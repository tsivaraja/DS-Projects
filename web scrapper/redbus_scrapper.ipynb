# %%
''' Main module to scrap Redbus.in '''
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException
import traceback
import logging
from selenium.webdriver.common.keys import Keys
import pymysql

# %%
'''Function to get details of each RTC. @input is url for one RTC'''
def getRTCDetails(rtcURL):
    routes = {}
    try:
        print (rtcURL)
        rtcDriver = webdriver.Chrome()
        rtcDriver.get(rtcURL)
        delaySecs = 15
        page_loaded = EC.presence_of_element_located((By.CLASS_NAME,'DC_117_pageTabs'))
        WebDriverWait(rtcDriver,delaySecs).until(page_loaded)
        #pages = rtcDriver.find_elements(By.CLASS_NAME,'DC_117_pageTabs')
        #print(len(pages))
        routes = getRoutes(rtcDriver)
        for routeName in routes:
            getBuses(rtcDriver,routeName, routes[routeName])
    except TimeoutException:
        print('No routes found for ',rtcURL)
    except Exception as e:
        print(traceback.format_exc())
    finally:
        print(routes)
        rtcDriver.quit()

# %%
'''Function to collect route details for the given RTC. Details include Route Name & URL for the Route'''
def getRoutes(pDriver):
    routeURLs = {}
    try:
        pageTable = pDriver.find_element(By.CLASS_NAME, 'DC_117_paginationTable')
        #Scroll to pagination table, otherwise click event will not be enabled
        pDriver.execute_script("arguments[0].scrollIntoView();", pageTable)
        pages = pDriver.find_elements(By.CLASS_NAME,'DC_117_pageTabs')
        # loop through the pages and get route details
        isFirst = True
        delaySecs = 15
        for page in pages:
            page.click()
            page_loaded = EC.presence_of_element_located((By.CLASS_NAME,'route'))
            WebDriverWait(pDriver,delaySecs).until(page_loaded)
                
            routeLinks = pDriver.find_elements(By.CLASS_NAME,'route')
            for route in routeLinks:
                routeURLs.setdefault(route.text,route.get_attribute('href'))
                # routeURLs.append(route.get_attribute('href'))
            isFirst = False
        return routeURLs
    except Exception as e:
        print(traceback.format_exc())
        raise e

# %%
''' Function to get buses on a given route'''
''' Inputs: active webdriver, route dictionary '''
def scroll_down(elem, num):
    for _ in range(num):
        time.sleep(.01)
        elem.send_keys(Keys.PAGE_DOWN)

#scroll the page till bottom to load all buses
def scroll_page(pDriver):
    SCROLL_PAUSE_TIME = 2
    elem = pDriver.find_element(By.TAG_NAME,"body")
    prev_height = elem.get_attribute("scrollHeight")
    for i in range(0, 500):
        # note that the pause between page downs is only .01 seconds
        # in this case that would be a sum of 1 second waiting time
        scroll_down(elem,100)
        # Wait to allow new items to load
        time.sleep(SCROLL_PAUSE_TIME)

        #check to see if scrollable space got larger
        #also we're waiting until the second iteration to give time for the initial loading
        if elem.get_attribute("scrollHeight") == prev_height and i > 0:
            break
        prev_height = elem.get_attribute("scrollHeight")     
        
def getBuses(pDriver,routeName,routeURL):
    try:
        url = routeURL
        pDriver.get(url)
        delaySecs = 15
        page_loaded = EC.presence_of_element_located((By.CLASS_NAME,'bus-items'))
        WebDriverWait(pDriver,delaySecs).until(page_loaded)
        # if there are any govt buses, click & expand them 
        resultSection = pDriver.find_element(By.ID,'result-section')
        groupData = resultSection.find_elements(By.CLASS_NAME,'group-data')
        i = len(groupData)
        # if there are more than one govt bus services, start from bottom
        # otherwise endless scroll will hide the View button making in unclickable
        while (i > 0):
            button = groupData[i-1].find_element(By.CLASS_NAME,'button')
            #pDriver.execute_script("arguments[0].scrollIntoView();", button)
            button.click()
            pDriver.find_element(By.TAG_NAME,'body').send_keys(Keys.PAGE_UP)
            i = i - 1
        
        scroll_page(pDriver)
        busItems = pDriver.find_elements(By.CLASS_NAME,'bus-items')
        print('Number of busItems : ', len(busItems))
        
        insertBusDetails(busItems,routeName,routeURL)
        
        
    except Exception as e:
        print(traceback.format_exc())
        raise e

# %%
''' Parse and insert bus details '''
def insertBusDetails(busItems,routeName,routeURL):
#     db_cols = ['route_name','route_link','bus_name','bus_type','depart_time','duration','arrival_time',
#               'rating','price','seats_available','depart_loc','arrival_loc']
    try:
        #Todo: this function call insert per row... efficient method is to call multiple inserts or df to sql
        conn = pymysql.connect(host='localhost', 
            user='root',  
            password = "Stars@4321", 
            db='redbus', 
            ) 
        cur  = conn.cursor()
        for busItem in busItems:
            buses = busItem.find_elements(By.CLASS_NAME,'bus-item-details')
            for bus in buses:
                try:
                    busName = bus.find_element(By.CLASS_NAME, 'travels').text
                    busType = bus.find_element(By.CLASS_NAME, 'bus-type').text
                    depTime = bus.find_element(By.CLASS_NAME, 'dp-time').text
                    depLoc = bus.find_element(By.CLASS_NAME, 'dp-loc').text
                    duration = bus.find_element(By.CLASS_NAME, 'dur').text
                    arrivalTime = bus.find_element(By.CLASS_NAME, 'bp-time').text
                    arrivalLoc = bus.find_element(By.CLASS_NAME, 'bp-loc').text
                    rating = bus.find_element(By.CLASS_NAME, 'rating-sec').text
                    rating = float(rating) if is_float(rating) else 0
                    fare = bus.find_element(By.CLASS_NAME, 'fare').text
                    fare = extract_fare(fare)
                    seatsLeft = bus.find_element(By.CLASS_NAME, 'seat-left').text
                    seatsLeft = extract_seats(seatsLeft)
                    # windowsLeft = bus.find_element(By.CLASS_NAME, 'window-left').text
                    # print(routeName,routeURL,busName,busType,depTime,depLoc,duration,arrivalTime,arrivalLoc,rating,fare,seatsLeft)
                    query = f"INSERT INTO bus_routes1 (route_name,route_link,bus_name,bus_type,depart_time,duration, \
                                arrival_time,rating,price,seats_available,depart_loc,arrival_loc) \
                                values(\"{routeName}\", \"{routeURL}\", \"{busName}\",\"{busType}\",\"{depTime}\", \
                               \"{duration}\",\"{arrivalTime}\",{rating},{fare},{seatsLeft},\"{depLoc}\",\"{arrivalLoc}\")"
                    cur.execute(query) 
                except NoSuchElementException as e:
                    print(f'Error inserting :{routeName} , {e.msg}')
                except Exception as e:
                    print(query)
                    print(f'Error inserting :{routeName} , {e.msg}')
        
    except Exception as e:
        print(query)
        print(f'Error inserting :{routeName} , {e.msg}')
    finally:
        conn.commit() 
        conn.close()
        print('inserted for ', routeName)

# split 'INR 100' string and extract int
def extract_fare(s):
    splits = s.split(' ')
    if is_float(splits[len(splits)-1]):
        return float(splits[len(splits)-1])
    else:
        return 200

def extract_seats(s):
    splits = s.split(' ')
    if is_int(splits[0]):
        return int(splits[0])
    else:
        return 1 


#check whether string can be converted to float
def is_float(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

#check whether string is a number
def is_int(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

# %%
#Load driver and load home page
chromeOptions = webdriver.ChromeOptions()
chromeOptions.headless = True
driver = webdriver.Chrome(options=chromeOptions)  

#Load Page
driver.get('https://www.redbus.in/');

# Find URL for RTC directory and load the page in the same tab
delaySecs = 10
element_present = EC.presence_of_element_located((By.CLASS_NAME,'rtcHeadViewAll'))
WebDriverWait(driver,delaySecs).until(element_present)
viewAll = driver.find_element(By.CLASS_NAME,'rtcHeadViewAll')
viewAllUrl = viewAll.find_element(By.TAG_NAME,'a')
# print(viewAllUrl.get_attribute('href'))
# print(viewAll.text)
# print(driver.current_url)
driver.get(viewAllUrl.get_attribute('href'))
# print(driver.current_url)

# Get URLs for RTCs which has routes... 
# TNSTC doesn't have any routes, we can ignore them
rtc_links_present = EC.presence_of_element_located((By.CLASS_NAME,'D113_ul_rtc'))
WebDriverWait(driver,delaySecs).until(rtc_links_present)
rtcList = driver.find_element(By.CLASS_NAME,'D113_ul_rtc')
rtcLinks = rtcList.find_elements(By.CLASS_NAME,'D113_link')
print(rtcLinks[0].text)

# skip first 4 as they don't have any routes
# TODO: right way to check is, load the page and check for routes list

rtcURLs = []
for link in rtcLinks[4:]:
    rtcURLs.append(link.get_attribute('href'))
print(len(rtcURLs))
driver.quit()
# Out:
# TNSTC
# 21

# %%
#test for one url

# routes = {}
# routes = getRTCDetails(rtcURLs[0])
# busRoute = 'https://www.redbus.in/bus-tickets/visakhapatnam-to-vijayawada'
# pDriver = webdriver.Chrome()
# getBuses(pDriver,'test',busRoute)
# pDriver.quit()


for link in rtcURLs:
    getRTCDetails(link)
# Out:
# https://www.redbus.in/online-booking/apsrtc
# Number of busItems :  3
# inserted for  Vijayawada to Hyderabad
# Number of busItems :  3
# inserted for  Hyderabad to Vijayawada
# Number of busItems :  2
# inserted for  Kakinada to Visakhapatnam
# Number of busItems :  2
# inserted for  Visakhapatnam to Kakinada
# Number of busItems :  2
# inserted for  Chittoor (Andhra Pradesh) to Bangalore
# Number of busItems :  2
# inserted for  Kadapa to Bangalore
# Number of busItems :  2
# inserted for  Anantapur (andhra pradesh) to Bangalore
# Number of busItems :  2
# Error inserting :Tirupati to Bangalore , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Error inserting :Tirupati to Bangalore , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Tirupati to Bangalore
# Number of busItems :  2
# Error inserting :Visakhapatnam to Vijayawada , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Visakhapatnam to Vijayawada
# Number of busItems :  3
# inserted for  Ongole to Hyderabad
# Number of busItems :  2
# Error inserting :Bangalore to Tirupati , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Error inserting :Bangalore to Tirupati , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Bangalore to Tirupati
# Number of busItems :  3
# inserted for  Macherla (andhra pradesh) to Hyderabad
# Number of busItems :  3
# inserted for  Rajahmundry to Visakhapatnam
# Number of busItems :  3
# inserted for  Nandyal to Hyderabad
# Number of busItems :  2
# inserted for  Bangalore to Kadapa
# Number of busItems :  3
# inserted for  Hyderabad to Ongole
# Traceback (most recent call last):
#   File "/var/folders/4l/kt6w5q250m38m9rqbvh4vqvh0000gn/T/ipykernel_12093/1189349524.py", line 42, in getBuses
#     button.click()
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webelement.py", line 94, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webelement.py", line 395, in _execute
#     return self._parent.execute(command, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py", line 354, in execute
#     self.error_handler.check_response(response)
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py", line 229, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: disconnected: Unable to receive message from renderer
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=126.0.6478.127)
# Stacktrace:
# 0   chromedriver                        0x0000000
'https://www.redbus.in/bus-tickets/hyderabad-to-kurnool', 'Hyderabad to Sathupally': 'https://www.redbus.in/bus-tickets/hyderabad-to-sathupalli', 'Hyderabad to Armoor': 'https://www.redbus.in/bus-tickets/hyderabad-to-armoor', 'Hyderabad to Godavarikhani': 'https://www.redbus.in/bus-tickets/hyderabad-to-godavarikhani', 'Hyderabad to Anantapur (andhra pradesh)': 'https://www.redbus.in/bus-tickets/hyderabad-to-ananthapur', 'Hyderabad to Warangal': 'https://www.redbus.in/bus-tickets/hyderabad-to-warangal', 'Hyderabad to Ongole': 'https://www.redbus.in/bus-tickets/hyderabad-to-ongole', 'Hyderabad to Guntur (Andhra Pradesh)': 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur', 'Kadapa to Hyderabad': 'https://www.redbus.in/bus-tickets/kadapa-to-hyderabad', 'Hyderabad to Tirupati': 'https://www.redbus.in/bus-tickets/hyderabad-to-tirupathi'}
# https://www.redbus.in/online-booking/bihar-state-tourism-development-corporation
# No routes found for  https://www.redbus.in/online-booking/bihar-state-tourism-development-corporation
# {}
# https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc
# Number of busItems :  2
# inserted for  Burdwan to Kolkata
# Number of busItems :  2
# Error inserting :Kolkata to Burdwan , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Kolkata to Burdwan
# Number of busItems :  3
# inserted for  Durgapur (West Bengal) to Kolkata
# Number of busItems :  2
# inserted for  Kolkata to Haldia
# Number of busItems :  2
# inserted for  Haldia to Kolkata
# Number of busItems :  3
# Error inserting :Kolkata to Durgapur (West Bengal) , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Kolkata to Durgapur (West Bengal)
# Number of busItems :  2
# inserted for  Kolkata to Arambagh (West Bengal)
# Number of busItems :  4
# Error inserting :Digha to Kolkata , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Digha to Kolkata
# Number of busItems :  4
# inserted for  Kolkata to Digha
# Number of busItems :  2
# inserted for  Kolkata to Bankura
# Number of busItems :  3
# inserted for  Asansol (West Bengal) to Kolkata
# Traceback (most recent call last):
#   File "/var/folders/4l/kt6w5q250m38m9rqbvh4vqvh0000gn/T/ipykernel_12093/1189349524.py", line 32, in getBuses
#     WebDriverWait(pDriver,delaySecs).until(page_loaded)
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/support/wait.py", line 105, in until
#     raise TimeoutException(message, screen, stacktrace)
# selenium.common.exceptions.TimeoutException: Message:
# Stacktrace:
# 0   chromedriver                        0x0000000102bcea80 chromedriver + 4385408
# 1   chromedriver                        0x0000000102bc738c chromedriver + 4354956
# 2   chromedriver                        0x00000001027e4b0c chromedriver + 281356
# 3   chromedriver                        0x00000001028272f8 chromedriver + 553720
# 4   chromedriver                        0x000000010285fd24 chromedriver + 785700
# 5   chromedriver                        0x000000010281beec chromedriver + 507628
# 6   chromedriver                        0x000000010281c8c4 chromedriver + 510148
# 7   chromedriver                        0x0000000102b9643c chromedriver + 4154428
# 8   chromedriver                        0x0000000102b9aea0 chromedriver + 4173472
# 9   chromedriver                        0x0000000102b7bff8 chromedriver + 4046840
# 10  chromedriver                        0x0000000102b9b78c chromedriver + 4175756
# 11  chromedriver                        0x0000000102b6efb8 chromedriver + 3993528
# 12  chromedriver                        0x0000000102bb921c chromedriver + 4297244
# 13  chromedriver                        0x0000000102bb9398 chromedriver + 4297624
# 14  chromedriver                        0x0000000102bc6f84 chromedriver + 4353924
# 15  libsystem_pthread.dylib             0x000000018c58ef94 _pthread_start + 136
# 16  libsystem_pthread.dylib             0x000000018c589d34 thread_start + 8
#
#
# No routes found for  https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc
# {'Burdwan to Kolkata': 'https://www.redbus.in/bus-tickets/burdwan-to-kolkata', 'Kolkata to Burdwan': 'https://www.redbus.in/bus-tickets/kolkata-to-burdwan', 'Durgapur (West Bengal) to Kolkata': 'https://www.redbus.in/bus-tickets/durgapur-to-kolkata', 'Kolkata to Haldia': 'https://www.redbus.in/bus-tickets/kolkata-to-haldia', 'Haldia to Kolkata': 'https://www.redbus.in/bus-tickets/haldia-to-kolkata', 'Kolkata to Durgapur (West Bengal)': 'https://www.redbus.in/bus-tickets/kolkata-to
West Bengal)': 'https://www.redbus.in/bus-tickets/kolkata-to-kirnahar-west-bengal', 'Durgapur (West Bengal) to Bankura': 'https://www.redbus.in/bus-tickets/durgapur-to-bankura', 'Siliguri to Malda': 'https://www.redbus.in/bus-tickets/siliguri-to-malda', 'Kolkata to Suri': 'https://www.redbus.in/bus-tickets/kolkata-to-suri', 'Purulia to Durgapur  ...
# https://www.redbus.in/online-booking/west-bengal-transport-corporation
# No routes found for  https://www.redbus.in/online-booking/west-bengal-transport-corporation
# {}
# https://www.redbus.in/online-booking/north-bengal-state-transport-corporation
# Number of busItems :  2
# inserted for  Kolkata to Siliguri
# Number of busItems :  2
# inserted for  Siliguri to Kolkata
# Number of busItems :  1
# inserted for  Siliguri to Darjeeling
# Number of busItems :  2
# inserted for  Kolkata to Raiganj
# Number of busItems :  2
# inserted for  Raiganj to Kolkata
# Number of busItems :  2
# inserted for  Kolkata to Malda
# Number of busItems :  2
# inserted for  Cooch Behar (West Bengal) to Berhampore (West Bengal)
# Number of busItems :  1
# inserted for  Kolkata to Cooch Behar (West Bengal)
# Number of busItems :  2
# inserted for  Malda to Kolkata
# Number of busItems :  1
# inserted for  Berhampore (West Bengal) to Cooch Behar (West Bengal)
# Number of busItems :  1
# inserted for  Cooch Behar (West Bengal) to Kolkata
# Number of busItems :  2
# inserted for  Kolkata to Balurghat
# Number of busItems :  1
# inserted for  Berhampore (West Bengal) to Siliguri
# Number of busItems :  1
# inserted for  Siliguri to Berhampore (West Bengal)
# Number of busItems :  1
# inserted for  Kolkata to Gangarampur
# Traceback (most recent call last):
#   File "/var/folders/4l/kt6w5q250m38m9rqbvh4vqvh0000gn/T/ipykernel_12093/1189349524.py", line 32, in getBuses
#     WebDriverWait(pDriver,delaySecs).until(page_loaded)
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/support/wait.py", line 105, in until
#     raise TimeoutException(message, screen, stacktrace)
# selenium.common.exceptions.TimeoutException: Message:
# Stacktrace:
# 0   chromedriver                        0x0000000104872a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010486b38c chromedriver + 4354956
# 2   chromedriver                        0x0000000104488b0c chromedriver + 281356
# 3   chromedriver                        0x00000001044cb2f8 chromedriver + 553720
# 4   chromedriver                        0x0000000104503d24 chromedriver + 785700
# 5   chromedriver                        0x00000001044bfeec chromedriver + 507628
# 6   chromedriver                        0x00000001044c08c4 chromedriver + 510148
# 7   chromedriver                        0x000000010483a43c chromedriver + 4154428
# 8   chromedriver                        0x000000010483eea0 chromedriver + 4173472
# 9   chromedriver                        0x000000010481fff8 chromedriver + 4046840
# 10  chromedriver                        0x000000010483f78c chromedriver + 4175756
# 11  chromedriver                        0x0000000104812fb8 chromedriver + 3993528
# 12  chromedriver                        0x000000010485d21c chromedriver + 4297244
# 13  chromedriver                        0x000000010485d398 chromedriver + 4297624
# 14  chromedriver                        0x000000010486af84 chromedriver + 4353924
# 15  libsystem_pthread.dylib             0x000000018c58ef94 _pthread_start + 136
# 16  libsystem_pthread.dylib             0x000000018c589d34 thread_start + 8
#
#
# No routes found for  https://www.redbus.in/online-booking/north-bengal-state-transport-corporation
# {'Kolkata to Siliguri': 'https://www.redbus.in/bus-tickets/kolkata-to-siliguri', 'Siliguri to Kolkata': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Siliguri to Darjeeling': 'https://www.redbus.in/bus-tickets/siliguri-to-darjeeling', 'Kolkata to Raiganj': 'https://www.redbus.in/bus-tickets/kolkata-to-raiganj', 'Raiganj to Kolkata': 'https://www.redbus.in/bus-tickets/raiganj-to-kolkata', 'Kolkata to Malda': 'https://www.redbus.in/bus-tickets/kolkata-to-malda', 'Cooch Behar (West Bengal) to Berhampore (West Bengal)': 'https://www.redbus.in/bus-tickets/cooch-behar-west-bengal-to
West Bengal)': 'https://www.redbus.in/bus-tickets/kolkata-to-itahar-west-bengal', 'Cooch Behar  ...
# https://www.redbus.in/online-booking/bsrtc-operated-by-vip-travels
# No routes found for  https://www.redbus.in/online-booking/bsrtc-operated-by-vip-travels
# {}
# https://www.redbus.in/online-booking/wbtc-ctc
# Number of busItems :  3
# inserted for  Durgapur (West Bengal) to Kolkata
# Number of busItems :  3
# inserted for  Digha to Barasat (West Bengal)
# Number of busItems :  3
# inserted for  Barasat (West Bengal) to Digha
# Traceback (most recent call last):
#   File "/var/folders/4l/kt6w5q250m38m9rqbvh4vqvh0000gn/T/ipykernel_12093/1189349524.py", line 32, in getBuses
#     WebDriverWait(pDriver,delaySecs).until(page_loaded)
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/support/wait.py", line 105, in until
#     raise TimeoutException(message, screen, stacktrace)
# selenium.common.exceptions.TimeoutException: Message:
# Stacktrace:
# 0   chromedriver                        0x000000010285aa80 chromedriver + 4385408
# 1   chromedriver                        0x000000010285338c chromedriver + 4354956
# 2   chromedriver                        0x0000000102470b0c chromedriver + 281356
# 3   chromedriver                        0x00000001024b32f8 chromedriver + 553720
# 4   chromedriver                        0x00000001024ebd24 chromedriver + 785700
# 5   chromedriver                        0x00000001024a7eec chromedriver + 507628
# 6   chromedriver                        0x00000001024a88c4 chromedriver + 510148
# 7   chromedriver                        0x000000010282243c chromedriver + 4154428
# 8   chromedriver                        0x0000000102826ea0 chromedriver + 4173472
# 9   chromedriver                        0x0000000102807ff8 chromedriver + 4046840
# 10  chromedriver                        0x000000010282778c chromedriver + 4175756
# 11  chromedriver                        0x00000001027fafb8 chromedriver + 3993528
# 12  chromedriver                        0x000000010284521c chromedriver + 4297244
# 13  chromedriver                        0x0000000102845398 chromedriver + 4297624
# 14  chromedriver                        0x0000000102852f84 chromedriver + 4353924
# 15  libsystem_pthread.dylib             0x000000018c58ef94 _pthread_start + 136
# 16  libsystem_pthread.dylib             0x000000018c589d34 thread_start + 8
#
#
# No routes found for  https://www.redbus.in/online-booking/wbtc-ctc
# {'Durgapur (West Bengal) to Kolkata': 'https://www.redbus.in/bus-tickets/durgapur-to-kolkata', 'Digha to Barasat (West Bengal)': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'Barasat (West Bengal) to Digha': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-digha', 'Suri to Kolkata': 'https://www.redbus.in/bus-tickets/suri-to-kolkata', 'Kolkata to Digha': 'https://www.redbus.in/bus-tickets/kolkata-to-digha', 'Bolpur (West Bengal) to Kolkata': 'https://www.redbus.in/bus-tickets/bolpur-west-bengal-to-kolkata', 'Kolkata to Suri': 'https://www.redbus.in/bus-tickets/kolkata-to-suri', 'Digha to Kolkata': 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Kolkata to Durgapur (West Bengal)': 'https://www.redbus.in/bus-tickets/kolkata-to-durgapur', 'Habra to Digha': 'https://www.redbus.in/bus-tickets/habra-to-digha', 'Barasat (West Bengal) to Nandakumar (west bengal)': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-nandakumar', 'Asansol (West Bengal) to Kolkata': 'https://www.redbus.in/bus-tickets/asansol-to-kolkata', 'Barasat (West Bengal) to Contai (Kanthi)': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-contai-kanthi', 'Siliguri to Kolkata': 'https://www.redbus.in/bus-tickets/siliguri-to-kolkata', 'Kolkata to Bolpur (West Bengal)': 'https://www.redbus.in/bus-tickets/kolkata-to-bolpur-west-bengal', 'Barasat (West Bengal) to Midnapore': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-midnapore', 'Barasat (West Bengal) to Kolaghat': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-kolaghat', 'Barasat (West Bengal) to Durgapur (West Bengal)': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-durgapur', 'Barasat (West Bengal) to Heria': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-heria', 'Digha to Habra': 'https://www.redbus.in/bus-tickets/digha-to-habra', 'Midnapore to Barasat (West Bengal)': 'https://www.redbus.in/bus-tickets/midnapore-to-barasat-west-bengal', 'Haldia to Barasat (West Bengal)': 'https://www.redbus.in/bus-tickets/haldia-to-barasat-west-bengal', 'Barasat (West Bengal) to Haldia': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-haldia', 'Midnapore to Kolkata': 'https://www.redbus.in/bus-tickets/midnapore-to-kolkata', 'Durgapur (West Bengal) to Purulia': 'https://www.redbus.in/bus-tickets/durgapur-to-purulia', 'Barasat (West Bengal) to Burdwan': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-burdwan', 'Kolkata to Siliguri': 'https://www.redbus.in/bus-tickets/kolkata-to-siliguri', 'Durgapur (West Bengal) to Barasat (West Bengal)': 'https://www.redbus.in/bus-tickets/durgapur-to-barasat-west-bengal', 'Haldia to Kolkata': 'https://www.redbus.in/bus-tickets/haldia-to-kolkata', 'Kolkata to Purulia': 'https://www.redbus.in/bus-tickets/kolkata-to-purulia', 'Kolkata to Asansol (West Bengal)': 'https://www.redbus.in/bus-tickets/kolkata-to-asansol', 'Barasat (West Bengal) to Debra': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-debra', 'Barasat (West Bengal) to Asansol (West Bengal)': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-asansol', 'Kolkata to Bakkhali': 'https://www.redbus.in/bus-tickets/kolkata-to-bakkhali', 'Barasat (West Bengal) to Nimtouri': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-nimtouri', 'Habra to Kolaghat': 'https://www.redbus.in/bus-tickets/habra-to-kolaghat', 'Habra to Durgapur (West Bengal)': 'https://www.redbus.in/bus-tickets/habra-to-durgapur', 'Barasat (West Bengal) to Mechogram': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-mechogram', 'Habra to Haldia': 'https://www.redbus.in/bus-tickets/habra-to-haldia', 'Habra to Contai (Kanthi)': 'https://www.redbus.in/bus-tickets/habra-to-contai-kanthi', 'Habra to Midnapore': 'https://www.redbus.in/bus-tickets/habra-to-midnapore'}
# https://www.redbus.in/online-booking/bihar-state-road-transport-corporation-bsrtc
# Number of busItems :  2
# inserted for  Patna (Bihar) to Bettiah
# Number of busItems :  1
# Error inserting :Gopalganj (Bihar) to Delhi , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Gopalganj (Bihar) to Delhi
# Number of busItems :  2
# inserted for  Patna (Bihar) to Motihari
# Number of busItems :  1
# inserted for  Delhi to Motihari
# Number of busItems :  2
# inserted for  Bettiah to Patna (Bihar)
# Number of busItems :  1
# Error inserting :Motihari to Delhi , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Motihari to Delhi
# Number of busItems :  1
# inserted for  Patna (Bihar) to Balmiki Nagar (bihar)
# Number of busItems :  1
# inserted for  Balmiki Nagar (bihar) to Patna (Bihar)
# Number of busItems :  1
# inserted for  Patna (Bihar) to Kathmandu
# Number of busItems :  1
# inserted for  Patna (Bihar) to Katihar
# Number of busItems :  1
# inserted for  Patna (Bihar) to Purnea
# Number of busItems :  1
# Error inserting :Patna (Bihar) to Hazaribagh , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Error inserting :Patna (Bihar) to Hazaribagh , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Error inserting :Patna (Bihar) to Hazaribagh , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Patna (Bihar) to Hazaribagh
# Number of busItems :  1
# Error inserting :Ranchi to Patna (Bihar) , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Error inserting :Ranchi to Patna (Bihar) , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Ranchi to Patna (Bihar)
# Number of busItems :  1
# Error inserting :Hazaribagh to Patna (Bihar) , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Hazaribagh to Patna (Bihar)
# Number of busItems :  1
# inserted for  Patna (Bihar) to Raxaul
# Number of busItems :  1
# inserted for  Muzaffarpur (Bihar) to Kathmandu
# Number of busItems :  1
# Error inserting :Patna (Bihar) to Ranchi , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Error inserting :Patna (Bihar) to Ranchi , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Patna (Bihar) to Ranchi
# Number of busItems :  1
# inserted for  Muzaffarpur (Bihar) to Ranchi
# Number of busItems :  1
# inserted for  Kathmandu to Patna (Bihar)
# Number of busItems :  1
# Error inserting :Ranchi to Muzaffarpur (Bihar) , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Error inserting :Ranchi to Muzaffarpur (Bihar) , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Ranchi to Muzaffarpur (Bihar)
# Number of busItems :  2
# inserted for  Motihari to Lucknow
# Number of busItems :  1
# inserted for  Lucknow to Motihari
# Number of busItems :  1
# inserted for  Motihari to Kathmandu
# Number of busItems :  1
# inserted for  Agra to Motihari
# Number of busItems :  1
# inserted for  Patna (Bihar) to Janakpur (Nepal)
# Number of busItems :  1
# inserted for  Muzaffarpur (Bihar) to Hazaribagh
# Number of busItems :  1
# inserted for  Purnea to Patna (Bihar)
# Number of busItems :  1
# inserted for  Patna (Bihar) to Araria (Bihar)
# Number of busItems :  2
# inserted for  Darbhanga to Patna (Bihar)
# Number of busItems :  1
# inserted for  Patna (Bihar) to Saharsa
# Number of busItems :  1
# inserted for  Motihari to Agra
# Number of busItems :  1
# inserted for  Hajipur (Bihar) to Kathmandu
# Number of busItems :  1
# inserted for  Kathmandu to Motihari
# Number of busItems :  1
# inserted for  Patna (Bihar) to Forbesganj
# Number of busItems :  1
# Error inserting :Ranchi to Hajipur (Bihar) , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Error inserting :Ranchi to Hajipur (Bihar) , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Ranchi to Hajipur (Bihar)
# Number of busItems :  1
# inserted for  Lucknow to Gopalganj (Bihar)
# ...
# 3   chromedriver                        0x00000001002ab2f8 chromedriver + 553720
# 4   chromedriver                        0x00000001002e3d24 chromedriver + 785700
# 5   chromedriver                        0x000000010029feec chromedriver + 507628
# 6   chromedriver                        0x00000001002a08c4 chromedriver + 510148
# 7   chromedriver                        0x000000010061a43c chromedriver + 4154428
# 8   chromedriver                        0x000000010061eea0 chromedriver + 4173472
# 9   chromedriver                        0x00000001005ffff8 chromedriver + 4046840
# 10  chromedriver                        0x000000010061f78c chromedriver + 4175756
# 11  chromedriver                        0x00000001005f2fb8 chromedriver + 3993528
# 12  chromedriver                        0x000000010063d21c chromedriver + 4297244
# 13  chromedriver                        0x000000010063d398 chromedriver + 4297624
# 14  chromedriver                        0x000000010064af84 chromedriver + 4353924
# 15  libsystem_pthread.dylib             0x000000018c58ef94 _pthread_start + 136
# 16  libsystem_pthread.dylib             0x000000018c589d34 thread_start + 8
#
#
# No routes found for  https://www.redbus.in/online-booking/sikkim-nationalised-transport-snt
# {'Gangtok to Siliguri': 'https://www.redbus.in/bus-tickets/gangtok-to-siliguri', 'Siliguri to Gangtok': 'https://www.redbus.in/bus-tickets/siliguri-to-gangtok', 'Siliguri to Rangpo': 'https://www.redbus.in/bus-tickets/siliguri-to-rangpo', 'Rangpo to Siliguri': 'https://www.redbus.in/bus-tickets/rangpo-to-siliguri', 'Siliguri to Pelling (Sikkim)': 'https://www.redbus.in/bus-tickets/siliguri-to-pelling-sikkim', 'Pelling (Sikkim) to Siliguri': 'https://www.redbus.in/bus-tickets/pelling-sikkim-to-siliguri', 'Ravangla (Sikkim) to Siliguri': 'https://www.redbus.in/bus-tickets/ravangla-sikkim-to-siliguri', 'Siliguri to Jorethang (Sikkim)': 'https://www.redbus.in/bus-tickets/siliguri-to-jorethang-sikkim', 'Singtham (Sikkim) to Siliguri': 'https://www.redbus.in/bus-tickets/singtham-sikkim-to-siliguri', 'Siliguri to Singtham (Sikkim)': 'https://www.redbus.in/bus-tickets/siliguri-to-singtham-sikkim', 'Siliguri to Namchi (Sikkim)': 'https://www.redbus.in/bus-tickets/siliguri-to-namchi-sikkim', 'Siliguri to Ravangla (Sikkim)': 'https://www.redbus.in/bus-tickets/siliguri-to-ravangla-sikkim', 'Jorethang (Sikkim) to Siliguri': 'https://www.redbus.in/bus-tickets/jorethang-sikkim-to-siliguri', 'Namchi (Sikkim) to Siliguri': 'https://www.redbus.in/bus-tickets/namchi-sikkim-to-siliguri', 'Siliguri to Melli (Sikkim)': 'https://www.redbus.in/bus-tickets/siliguri-to-melli-sikkim'}
# https://www.redbus.in/online-booking/meghalaya-transport-corporation-mtc
# Number of busItems :  2
# inserted for  Guwahati to Shillong
# Number of busItems :  1
# inserted for  Shillong to Tura (Meghalaya)
# Number of busItems :  2
# inserted for  Shillong to Guwahati
# Number of busItems :  1
# inserted for  Tura (Meghalaya) to Shillong
# Traceback (most recent call last):
#   File "/var/folders/4l/kt6w5q250m38m9rqbvh4vqvh0000gn/T/ipykernel_12093/1189349524.py", line 32, in getBuses
#     WebDriverWait(pDriver,delaySecs).until(page_loaded)
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/support/wait.py", line 105, in until
#     raise TimeoutException(message, screen, stacktrace)
# selenium.common.exceptions.TimeoutException: Message:
# Stacktrace:
# 0   chromedriver                        0x0000000104f4aa80 chromedriver + 4385408
# 1   chromedriver                        0x0000000104f4338c chromedriver + 4354956
# 2   chromedriver                        0x0000000104b60b0c chromedriver + 281356
# 3   chromedriver                        0x0000000104ba32f8 chromedriver + 553720
# 4   chromedriver                        0x0000000104bdbd24 chromedriver + 785700
# 5   chromedriver                        0x0000000104b97eec chromedriver + 507628
# 6   chromedriver                        0x0000000104b988c4 chromedriver + 510148
# 7   chromedriver                        0x0000000104f1243c chromedriver + 4154428
# 8   chromedriver                        0x0000000104f16ea0 chromedriver + 4173472
# 9   chromedriver                        0x0000000104ef7ff8 chromedriver + 4046840
# 10  chromedriver                        0x0000000104f1778c chromedriver + 4175756
# 11  chromedriver                        0x0000000104eeafb8 chromedriver + 3993528
# 12  chromedriver                        0x0000000104f3521c chromedriver + 4297244
# 13  chromedriver                        0x0000000104f35398 chromedriver + 4297624
# 14  chromedriver                        0x0000000104f42f84 chromedriver + 4353924
# 15  libsystem_pthread.dylib             0x000000018c58ef94 _pthread_start + 136
# 16  libsystem_pthread.dylib             0x000000018c589d34 thread_start + 8
#
#
# No routes found for  https://www.redbus.in/online-booking/meghalaya-transport-corporation-mtc
# {'Guwahati to Shillong': 'https://www.redbus.in/bus-tickets/guwahati-to-shillong', 'Shillong to Tura (Meghalaya)': 'https://www.redbus.in/bus-tickets/shillong-to-tura-meghalaya', 'Shillong to Guwahati': 'https://www.redbus.in/bus-tickets/shillong-to-guwahati', 'Tura (Meghalaya) to Shillong': 'https://www.redbus.in/bus-tickets/tura-meghalaya-to-shillong', 'Shillong to Silchar': 'https://www.redbus.in/bus-tickets/shillong-to-silchar', 'Silchar to Shillong': 'https://www.redbus.in/bus-tickets/silchar-to-shillong', 'Shillong to Karimganj': 'https://www.redbus.in/bus-tickets/shillong-to-karimganj', 'Shillong to Williamnagar (Meghalaya)': 'https://www.redbus.in/bus-tickets/shillong-to-williamnagar-meghalaya', 'Karimganj to Shillong': 'https://www.redbus.in/bus-tickets/karimganj-to-shillong', 'Williamnagar (Meghalaya) to Shillong': 'https://www.redbus.in/bus-tickets/williamnagar-meghalaya-to-shillong', 'Shillong to Hailakandi': 'https://www.redbus.in/bus-tickets/shillong-to-hailakandi', 'Shillong to Ramkrishnanagar': 'https://www.redbus.in/bus-tickets/shillong-to-ramkrishnanagar', 'Hailakandi to Shillong': 'https://www.redbus.in/bus-tickets/hailakandi-to-shillong', 'Ramkrishnanagar to Shillong': 'https://www.redbus.in/bus-tickets/ramkrishnanagar-to-shillong', 'Shillong to Phulbari': 'https://www.redbus.in/bus-tickets/shillong-to-phulbari'}
# https://www.redbus.in/online-booking/astc
# Number of busItems :  2
# Error inserting :Tezpur to Guwahati , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Tezpur to Guwahati
# Number of busItems :  2
# Error inserting :Guwahati to Tezpur , no such element: Unable to locate element: {"method":"css selector","selector":".rating-sec"}
#   (Session info: chrome=126.0.6478.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# inserted for  Guwahati to Tezpur
# Traceback (most recent call last):
#   File "/var/folders/4l/kt6w5q250m38m9rqbvh4vqvh0000gn/T/ipykernel_12093/1189349524.py", line 32, in getBuses
#     WebDriverWait(pDriver,delaySecs).until(page_loaded)
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/support/wait.py", line 105, in until
#     raise TimeoutException(message, screen, stacktrace)
# selenium.common.exceptions.TimeoutException: Message:
# Stacktrace:
# 0   chromedriver                        0x0000000104cf2a80 chromedriver + 4385408
# 1   chromedriver                        0x0000000104ceb38c chromedriver + 4354956
# 2   chromedriver                        0x0000000104908b0c chromedriver + 281356
# 3   chromedriver                        0x000000010494b2f8 chromedriver + 553720
# 4   chromedriver                        0x0000000104983d24 chromedriver + 785700
# 5   chromedriver                        0x000000010493feec chromedriver + 507628
# 6   chromedriver                        0x00000001049408c4 chromedriver + 510148
# 7   chromedriver                        0x0000000104cba43c chromedriver + 4154428
# 8   chromedriver                        0x0000000104cbeea0 chromedriver + 4173472
# 9   chromedriver                        0x0000000104c9fff8 chromedriver + 4046840
# 10  chromedriver                        0x0000000104cbf78c chromedriver + 4175756
# 11  chromedriver                        0x0000000104c92fb8 chromedriver + 3993528
# 12  chromedriver                        0x0000000104cdd21c chromedriver + 4297244
# 13  chromedriver                        0x0000000104cdd398 chromedriver + 4297624
# 14  chromedriver                        0x0000000104ceaf84 chromedriver + 4353924
# 15  libsystem_pthread.dylib             0x000000018c58ef94 _pthread_start + 136
# 16  libsystem_pthread.dylib             0x000000018c589d34 thread_start + 8
#
#
# No routes found for  https://www.redbus.in/online-booking/astc
# {'Tezpur to Guwahati': 'https://www.redbus.in/bus-tickets/tezpur-to-guwahati', 'Guwahati to Tezpur': 'https://www.redbus.in/bus-tickets/guwahati-to-tezpur', 'Nagaon (Assam) to Guwahati': 'https://www.redbus.in/bus-tickets/nagaon-to-guwahati', 'Guwahati to Nagaon (Assam)': 'https://www.redbus.in/bus-tickets/guwahati-to-nagaon', 'Goalpara to Guwahati': 'https://www.redbus.in/bus-tickets/goalpara-to-guwahati', 'Jorhat to North Lakhimpur': 'https://www.redbus.in/bus-tickets/jorhat-to-north-lakhimpur', 'Dhubri to Guwahati': 'https://www.redbus.in/bus-tickets/dhubri-to-guwahati', 'Guwahati to Dhubri': 'https://www.redbus.in/bus-tickets/guwahati-to-dhubri', 'North Lakhimpur to Sibsagar': 'https://www.redbus.in/bus-tickets/north-lakhimpur-to
 'https://www.redbus.in/bus-tickets/north-lakhimpur-to-moran', 'Tezpur to North Lakhimpur': 'https://www.redbus.in/bus-tickets/tezpur-to-north-lakhimpur', 'Tezpur to Tinsukia': 'https://www.redbus.in/bus-tickets/tezpur-to-tinsukia', 'Dibrugarh to Bihpuria': 'https://www.redbus.in/bus-tickets/dibrugarh-to-bihpuria', 'Dibrugarh to Bokakhat': 'https://www.redbus.in/bus-tickets/dibrugarh-to-bokakhat ...
# https://www.redbus.in/online-booking/kaac-transport
# Traceback (most recent call last):
#   File "/var/folders/4l/kt6w5q250m38m9rqbvh4vqvh0000gn/T/ipykernel_12093/1189349524.py", line 32, in getBuses
#     WebDriverWait(pDriver,delaySecs).until(page_loaded)
#   File "/opt/anaconda3/lib/python3.11/site-packages/selenium/webdriver/support/wait.py", line 105, in until
#     raise TimeoutException(message, screen, stacktrace)
# selenium.common.exceptions.TimeoutException: Message:
# Stacktrace:
# 0   chromedriver                        0x0000000103296a80 chromedriver + 4385408
# 1   chromedriver                        0x000000010328f38c chromedriver + 4354956
# 2   chromedriver                        0x0000000102eacb0c chromedriver + 281356
# 3   chromedriver                        0x0000000102eef2f8 chromedriver + 553720
# 4   chromedriver                        0x0000000102f27d24 chromedriver + 785700
# 5   chromedriver                        0x0000000102ee3eec chromedriver + 507628
# 6   chromedriver                        0x0000000102ee48c4 chromedriver + 510148
# 7   chromedriver                        0x000000010325e43c chromedriver + 4154428
# 8   chromedriver                        0x0000000103262ea0 chromedriver + 4173472
# 9   chromedriver                        0x0000000103243ff8 chromedriver + 4046840
# 10  chromedriver                        0x000000010326378c chromedriver + 4175756
# 11  chromedriver                        0x0000000103236fb8 chromedriver + 3993528
# 12  chromedriver                        0x000000010328121c chromedriver + 4297244
# 13  chromedriver                        0x0000000103281398 chromedriver + 4297624
# 14  chromedriver                        0x000000010328ef84 chromedriver + 4353924
# 15  libsystem_pthread.dylib             0x000000018c58ef94 _pthread_start + 136
# 16  libsystem_pthread.dylib             0x000000018c589d34 thread_start + 8
#
#
# No routes found for  https://www.redbus.in/online-booking/kaac-transport
# {'Diphu to Guwahati': 'https://www.redbus.in/bus-tickets/diphu-to-guwahati', 'Guwahati to Diphu': 'https://www.redbus.in/bus-tickets/guwahati-to-diphu', 'Bokolia (assam) to Guwahati': 'https://www.redbus.in/bus-tickets/bokolia-assam-to-guwahati', 'Dokmoka to Guwahati': 'https://www.redbus.in/bus-tickets/dokmoka-to-guwahati', 'Guwahati to Dokmoka': 'https://www.redbus.in/bus-tickets/guwahati-to-dokmoka', 'Guwahati to Bokolia (assam)': 'https://www.redbus.in/bus-tickets/guwahati-to-bokolia-assam', 'Langhin (assam) to Guwahati': 'https://www.redbus.in/bus-tickets/langhin-assam-to-guwahati', 'Diphu to Hamren': 'https://www.redbus.in/bus-tickets/diphu-to-hamren', 'Guwahati to Langhin (assam)': 'https://www.redbus.in/bus-tickets/guwahati-to-langhin-assam', 'Guwahati to Manja (assam)': 'https://www.redbus.in/bus-tickets/guwahati-to-manja-assam', 'Manja (assam) to Guwahati': 'https://www.redbus.in/bus-tickets/manja-assam-to-guwahati', 'Hamren to Diphu': 'https://www.redbus.in/bus-tickets/hamren-to-diphu'}
# https://www.redbus.in/online-booking/gsrtc
# No routes found for  https://www.redbus.in/online-booking/gsrtc
# {}
